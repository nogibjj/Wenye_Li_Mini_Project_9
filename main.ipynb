# %%
from mylib.lib import *

# %%
data = load_dataset()
data.head()
# Out:
#   age     n  alcohol_use  alcohol_frequency  marijuana_use  \
# 0  12  2798          3.9                3.0            1.1
# 1  13  2757          8.5                6.0            3.4
# 2  14  2792         18.1                5.0            8.7
# 3  15  2956         29.2                6.0           14.5
# 4  16  3058         40.1               10.0           22.5
#
#    marijuana_frequency  cocaine_use cocaine_frequency  crack_use  \
# 0                  4.0          0.1               5.0        0.0
# 1                 15.0          0.1               1.0        0.0
# 2                 24.0          0.1               5.5        0.0
# 3                 25.0          0.5               4.0        0.1
# 4                 30.0          1.0               7.0        0.0
#
#   crack_frequency  ...  oxycontin_use oxycontin_frequency  tranquilizer_use  \
# 0               -  ...            0.1                24.5               0.2
# ...

# %%
description = describe_dataset()
description
# Out:
#                  n  alcohol_use  alcohol_frequency  marijuana_use  \
# count    17.000000    17.000000          17.000000      17.000000
# mean   3251.058824    55.429412          33.352941      18.923529
# std    1297.890426    26.878866          21.318833      11.959752
# min    2223.000000     3.900000           3.000000       1.100000
# 25%    2469.000000    40.100000          10.000000       8.700000
# 50%    2798.000000    64.600000          48.000000      20.800000
# 75%    3058.000000    77.500000          52.000000      28.400000
# max    7391.000000    84.200000          52.000000      34.000000
#
#        marijuana_frequency  cocaine_use  crack_use  heroin_use  \
# count            17.000000    17.000000  17.000000   17.000000
# mean             42.941176     2.176471   0.294118    0.352941
# std              18.362566     1.816772   0.235772    0.333762
# min               4.000000     0.000000   0.000000    0.000000
# ...

# %%
print("The mean of the dataset is: ")
description.mean()
# Out:
# The mean of the dataset is:
# n                          2813.118656
# alcohol_use                  46.201035
# alcohol_frequency            29.583972
# marijuana_use                17.610410
# marijuana_frequency          36.037968
# cocaine_use                   4.049155
# crack_use                     2.378736
# heroin_use                    2.460838
# hallucinogen_use              5.110828
# hallucinogen_frequency       13.051501
# inhalant_use                  3.289440
# pain_releiver_use             7.017121
# pain_releiver_frequency      15.080123
# oxycontin_use                 2.892939
# tranquilizer_use              4.532408
# tranquilizer_frequency       15.465062
# stimulant_use                 3.728165
# stimulant_frequency          66.140106
# meth_use                      2.468139
# sedative_use                  2.352544
# sedative_frequency           25.276985
# dtype: float64

# %%
print("The std of the dataset is: ")
description.std()
# Out:
# The std of the dataset is:
# n                          2131.057365
# alcohol_use                  29.031702
# alcohol_frequency            19.549279
# marijuana_use                10.564247
# marijuana_frequency          22.640821
# cocaine_use                   5.478952
# crack_use                     5.911792
# heroin_use                    5.884728
# hallucinogen_use              5.489778
# hallucinogen_frequency       16.750402
# inhalant_use                  5.613043
# pain_releiver_use             5.062980
# pain_releiver_frequency       9.196877
# oxycontin_use                 5.726030
# tranquilizer_use              5.300344
# tranquilizer_frequency       15.243415
# stimulant_use                 5.514594
# stimulant_frequency         123.315810
# meth_use                      5.877944
# sedative_use                  5.920462
# sedative_frequency           32.609096
# dtype: float64

# %%
median_values = describe_median()

print("The median of the dataset is: ")
median_values
# Out:
# The median of the dataset is:
# n                          2798.0
# alcohol_use                  64.6
# alcohol_frequency            48.0
# marijuana_use                20.8
# marijuana_frequency          52.0
# cocaine_use                   2.0
# cocaine_frequency             5.0
# crack_use                     0.4
# crack_frequency               6.0
# heroin_use                    0.2
# heroin_frequency             50.0
# hallucinogen_use              3.2
# hallucinogen_frequency        3.0
# inhalant_use                  1.4
# inhalant_frequency            4.0
# pain_releiver_use             6.2
# pain_releiver_frequency      12.0
# oxycontin_use                 1.1
# oxycontin_frequency          12.0
# tranquilizer_use              3.5
# tranquilizer_frequency       10.0
# stimulant_use                 1.8
# stimulant_frequency          10.0
# meth_use                      0.4
# meth_frequency               24.0
# sedative_use                  0.3
# ...

# %%
plt.figure(figsize=(8, 6))

# Plotting the histogram
plt.hist(data['alcohol_use'], bins=10, edgecolor='black')
plt.xlabel('Alcohol Use (%)')
plt.ylabel('Frequency')
plt.title('Distribution of Alcohol Use')

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()
plt.close()

# %%
data_selected = data[['age', 'marijuana_use']]

plt.figure(figsize=(10, 6))
plt.plot(data_selected['age'], data_selected['marijuana_use'], label='Marijuana Use (%)', marker='o', color='g')

plt.xlabel('Age')
plt.ylabel('Marijuana Use (%)')
plt.title('Trend of Marijuana Use by Age')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
plt.close()

# %%
data_selected = data[['age', 'cocaine_use']]

plt.figure(figsize=(10, 6))
plt.bar(data_selected['age'], data_selected['cocaine_use'], color='orange')

plt.xlabel('Age')
plt.ylabel('Cocaine Use (%)')
plt.title('Cocaine Use by Age')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
plt.close()
